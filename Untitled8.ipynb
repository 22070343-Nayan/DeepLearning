# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression

# %%
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
print("Total Explained Variance:", sum(pca.explained_variance_ratio_))
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762]
# Total Explained Variance: 0.9581320720000166

# %%
plt.figure(figsize=(8, 6))
colors = ['navy', 'turquoise', 'darkorange']

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], alpha=0.8, color=color,
                label=target_name)

# %%
plt.legend()
plt.title('PCA of IRIS Dataset (2D Projection)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-4243144540.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
clf = LogisticRegression()
clf.fit(X_pca, y)
accuracy = clf.score(X_pca, y)
print(f"Classification accuracy on 2D PCA data: {accuracy:.2f}")
# Out:
# Classification accuracy on 2D PCA data: 0.93
